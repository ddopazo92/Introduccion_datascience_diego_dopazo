# %% [markdown]
# <a href="https://colab.research.google.com/github/ddopazo92/Introduccion_datascience_diego_dopazo/blob/main/cargar_csv_y_agrupar_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('Video_Games.csv', sep=';', usecols=['Name','Platform'] )
##df = pd.read_csv('Video_Games.csv', sep=';', usecols=[0,1],header=None )

df.head() ##metodo head() levanta top 5 registros
# Out:
#                     Name Platform
# 0             Wii Sports      Wii
# 1         Mario Kart Wii      Wii
# 2      Wii Sports Resort      Wii
# 3  New Super Mario Bros.       DS
# 4               Wii Play      Wii

# %% [markdown]
# # Subir **csv**

# %%
df.info() ##metodo que dice que tipo de datos tienen las columnas del csv(dataframe) cargado
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7435 entries, 0 to 7434
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             7435 non-null   object
#  1   Platform         7435 non-null   object
#  2   Year_of_Release  7435 non-null   int64
#  3   Genre            7435 non-null   object
#  4   Publisher        7433 non-null   object
#  5   NA_Sales         7435 non-null   float64
#  6   EU_Sales         7435 non-null   float64
#  7   JP_Sales         7435 non-null   float64
#  8   Other_Sales      7435 non-null   float64
#  9   Global_Sales     7435 non-null   float64
#  10  Critic_Score     6867 non-null   float64
#  11  Critic_Count     6867 non-null   float64
#  12  User_Score       7435 non-null   float64
#  13  User_Count       7435 non-null   int64
#  14  Developer        7424 non-null   object
#  15  Rating           7352 non-null   object
# ...

# %%
df.describe()
# Out:
#        Year_of_Release     NA_Sales     EU_Sales     JP_Sales  Other_Sales  \
# count      7435.000000  7435.000000  7435.000000  7435.000000  7435.000000
# mean       2007.687962     0.378238     0.226752     0.060095     0.080040
# std           4.297550     0.933143     0.663916     0.276583     0.260859
# min        1985.000000     0.000000     0.000000     0.000000     0.000000
# 25%        2004.000000     0.050000     0.020000     0.000000     0.010000
# 50%        2008.000000     0.140000     0.060000     0.000000     0.020000
# 75%        2011.000000     0.380000     0.200000     0.010000     0.070000
# max        2016.000000    41.360000    28.960000     6.500000    10.570000
#
#        Global_Sales  Critic_Score  Critic_Count   User_Score    User_Count
# count   7435.000000   6867.000000   6867.000000  7435.000000   7435.000000
# mean       0.745303     70.265327     28.854522     7.124640    163.157767
# ...

# %%
##columna_especifica = df['Year_of_Release']

##print(columna_especifica)

columna_condicion = df[df['Year_of_Release'] < 2005]

columna_condicion.head()
# Out:
#                              Name Platform  Year_of_Release   Genre  \
# 11  Grand Theft Auto: San Andreas      PS2             2004  Action
# 14    Grand Theft Auto: Vice City      PS2             2002  Action
# 16         Gran Turismo 3: A-Spec      PS2             2001  Racing
# 23           Grand Theft Auto III      PS2             2001  Action
# 30                 Gran Turismo 4      PS2             2004  Racing
#
#                       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 11         Take-Two Interactive      9.43      0.40      0.41        10.57
# 14         Take-Two Interactive      8.41      5.49      0.47         1.78
# 16  Sony Computer Entertainment      6.85      5.09      1.87         1.16
# 23         Take-Two Interactive      6.99      4.51      0.30         1.30
# 30  Sony Computer Entertainment      3.01      0.01      1.10         7.53
#
#     Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count  \
# ...

# %% [markdown]
# AGRUPACION DE DATOS   **group by**

# %%
agrupar = df.groupby('Platform')['Year_of_Release'].mean() ## Agrupo primero por columna que va en (), y los valores de la otra columna que va con []
                                                           ## con el metodo mean() asociado al Year_of_release te da el año promedio con mas registros de esa consola(columa seleccionada)

agrupar
# Out:
# Platform
# 3DS     2012.719298
# DC      2000.071429
# DS      2007.402750
# GBA     2003.123506
# GC      2003.329577
# PC      2009.051931
# PS      1999.367089
# PS2     2003.960461
# PS3     2010.445867
# PS4     2015.074219
# PSP     2007.242206
# PSV     2013.464286
# Wii     2008.473394
# WiiU    2013.660000
# X360    2009.775424
# XB      2003.650264
# XOne    2014.934066
# Name: Year_of_Release, dtype: float64

# %% [markdown]
# # ***Levantar archivo de excel xls xlms***

# %%
import pandas as pd

df = pd.read_excel('AirBnb-project-Diego Dopazo.xls',sheet_name='barrios') ##sheet_name= para seleccionar una hoja especifica del xlms
df.head()
# Out:
#         barrio  Id_barrio
# 0   Kensington          1
# 1      Midtown          2
# 2       Harlem          3
# 3  East Harlem          4
# 4  Murray Hill          5

# %%
import pandas as pd

df = pd.read_excel('AirBnb-project-Diego Dopazo.xls',na_values=['N/A', 'NA', '--']) ##sheet_name= para seleccionar una hoja especifica del xlms
df.head()
# Out:
#         id nombre_Anfitrion     ciudad       barrio        lat       long  \
# 0  1001254         Madaline   Brooklyn   Kensington  4064749.0 -7397237.0
# 1  1002102            Jenna  Manhattan      Midtown  4075362.0 -7398377.0
# 2  1002403            Elise  Manhattan       Harlem  4080902.0  -739419.0
# 3  1003689           Lyndon  Manhattan  East Harlem  4079851.0 -7394399.0
# 4  1004098         Michelle  Manhattan  Murray Hill  4074767.0   -73975.0
#
#             pais codigo_pais  reserva_inmediata politica_cancelacion  ...  \
# 0  United States          US                0.0               strict  ...
# 1  United States          US                0.0             moderate  ...
# 2  United States          US                1.0             flexible  ...
# 3  United States          US                0.0             moderate  ...
# 4  United States          US                1.0             flexible  ...
#
# ...
